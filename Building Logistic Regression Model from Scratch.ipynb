# %% [markdown]
# # Logistic Regression
# 1. Supervised Learning Model
# 2. Classification Model
# 3. Best for binary classification problem
# 4. Uses sigmoid function (S shaped Curved)
# ______________________________________________________________________________________________________
# ![image.png](attachment:21f04a30-8bb5-4abb-8ab1-c4503110544c.png)
# ______________________________________________________________________________________________________
# 1. Ȳ - Probability that (y = 1)
# 2. Ȳ  = P(Y=1 | X)
# 3. X - input features
# 4. w - weights ( number of weights is equal to the number of input features in a dataset)
# 5. b-bias
# 6. Ȳ = σ (Z)
# 7. it the probability is greater the 0.5 then it is p(yes) and less then 0.5 then p(no)
#
# _____________________________________________________________________________________________________
# Advantages:
# 1. Easy to implement
# 2. Performs well on data with linear relationship
# 3. Less prone to over-fitting for low dimensional dataset
# ______________________________________________________________________________________________________
# Disadvantages:
# 1. High dimensional dataset causes over-fitting
# 2. Difficult to capture complex relationships in a dataset
# 3. Sensitive to Outliers
# 4. Needs a larger dataset

# %% [markdown]
# ![image.png](attachment:da603bb4-f8fe-4eed-a701-bb4e06487814.png)
#
# ![image.png](attachment:bde832f9-8b68-4972-bc27-1a95247a93f1.png)

# %% [markdown]
# 1. To optimize the values of w and b, we have to use the Gradient Descent method.
# 2. In order to calculate the Gradient Descent, the loss function is very useful.
# ####  formula for Loss function in Logistic Regression
# We won't use the same formula for loss function as linear regression .Due to given graph
# ![image.png](attachment:725ce98c-7e9b-48fe-8c85-8f7d10456ad4.png)
#
# ##### ![image.png](attachment:a8f7b88b-f32e-4ae4-b97a-a2fc8dd0aa03.png)
# this formula is used
# ![image.png](attachment:de4c15b2-2b2d-483f-874e-95b56f4caefe.png)

# %% [markdown]
# #### Loss function(L): Used when we refer to the error for a single training example.
# ![image.png](attachment:0209ff2b-41ca-4706-851c-b4bc9052c60f.png)
# #### Cost function(J): Used to refer to an average of the loss functions over an entire training data.
# ![image.png](attachment:28078a19-4749-4c63-8599-b79bf918ad53.png)

# %% [markdown]
# ### Gradient Descent Part
# 1. w2 = w1 L*dw
# 2. b2 = b1 L*db
# 3. w --> weight
# 4. b --> bias
# 5. L--> Learning Rate
# 6. dw --> Partial Derivative of cost function with respect to w
# 7. db --> Partial Derivative of cost function with respect to b
# 8. ![image.png](attachment:7f223dcd-ca0d-4d17-8463-630a382b4da8.png)

# %% [markdown]
# Work flow of the Logistic Regression model:
# 1. Set Learning Rate & Number of Iterations; Initiate Random weight and bias value.
# 2. Build Logistic Regression Function. (sigmoid function)
# 3. Update the parameters using gradient descent.
# Finally we will get the best model (best weight and bias value) as it has minimum cost function.
# 4. build the "predict" function to determine the class of the data point.
